# %% [markdown]
# # Example of plotting with *matplotlib*
#
# Irina Overeem, September 2021.
#
# This notebook has two short learning objectives illustrated with a few simple examples.
# We learn to create variables, inquire about their data type, create a data array as a list, using the Python *numpy* package.
# And then we plot the data array using the Python *matplotlib* package.
#
# Begin by importing *numpy* and *matplotlib*. If you use the class jupyter hub these packages are installed for us.
# Also run a "magic" command that allows plots to be displayed directly in the notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib inline

# %% [markdown]
# Python, or any programming language, works with variables.
# A 'variable' is a name that is used to store data. It can be used to store different kinds of data, but here we consider a simple case where the data is a single numerical value. Here are a few examples

# %%
# a few arbitrary variables
a = 84
b,c = 10.5,5
d ='test'

# %% [markdown]
# Define some more complicated data (we are just making it up)

# %%
x = [10, 50, 100, 500]  # values for the x-axis
y = [2, 10, 60, 90]     # values for the y-axis

# %%
# here we ask what is the data type of the newly created data object, the command will return the datatype.
type(x)
# Out:
# list

# %%
# Exercise 1
# Find out the datatypes of variables b and d

# %% [markdown]
# There are a tons of plotting options. I show one I use frequently here.
# It creates a line plot of two variables plotted against each other.

# %%
# Really basic line plot
plt.plot(x, y)
plt.xlabel('One thing [units]')      # This creates the x-axis label
plt.ylabel('Another thing [units]')  # This creates the y-axis label
# Out:
# Text(0, 0.5, 'Another thing [units]')

# %%
# Some slightly fancier options
# You can modify a lot of options using various optional keyword arguments
plt.plot(x, y, color='b', linewidth=2, linestyle='--', marker='x', markersize=10)
plt.xlabel('One thing [units]', fontsize=16)
plt.ylabel('Another thing [units]', fontsize=16)
# Out:
# Text(0, 0.5, 'Another thing [units]')

# %% [markdown]
# Same thing but now adding another set of data, plus a title and legend:

# %%
y2 = [3, 9, 56, 99]
plt.plot(x, y, color='b', linewidth=2, linestyle='--', marker='x', markersize=10)
plt.plot(x, y2, color='r', linewidth=2, linestyle=':', marker='o', markersize=10)
plt.xlabel('One thing [units]', fontsize=16)
plt.ylabel('Another thing [units]', fontsize=16)
plt.title('One thing plotted against another', fontsize=18)
plt.legend(['Sample dataset 1', 'Sample dataset 2'], loc='upper left')

# %%
# Sometimes a line plot does not make sense, and instead you want to plot up data as a scatter plot.
# the example adds detail by cycling through the color scale and make label size proportional to value of y2.

s=y2
colors = y2

plt.scatter(x, y, c=colors, s=y2)
plt.show()

# %%
# here we create a 2D array, named im, using the numpy package. 
# we then plot a 2d mesh of this array

im = np.array([[1, 7, 3, 4,4], [5, 2, 7, 8,10], [9, 3, 11, 2,3],[7, 3, 10, 2,3]])
plt.pcolormesh(im, cmap=defau)
plt.show()

# %%
# Exercise 2
# create a 5 by 3 array of arbitrary values with an upward trend
# plot your array as a color mesh
